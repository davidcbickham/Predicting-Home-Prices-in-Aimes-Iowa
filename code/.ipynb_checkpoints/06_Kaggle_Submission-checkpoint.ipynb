# %% [markdown]
# # Kaggle Submission

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
import pickle
import numpy as np
np.random.seed(42)

# %% [markdown]
# ## Load in trained model and scaler

# %%
# !pwd
# Out:
# /Users/davidbickham/dsi/project_2/code

# %%
with open('../assets/scaler_1553209257.pkl', 'rb') as f:
    ss = pickle.load(f)
    
with open('../assets/lin_reg.pkl', 'rb') as f:
    lr = pickle.load(f)
    
with open('../assets/columns_1553209257.pkl', 'rb') as f:
    cols = pickle.load(f)

# %% [markdown]
# ## Load kaggle data

# %%
kaggle = pd.read_csv('../data/test.csv', index_col = 'Id',na_values='', keep_default_na=False)

# %%
kaggle.head()
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# Id
# 2658  902301120          190        RM          69.0      9142   Pave  Grvl
# 2718  905108090           90        RL           NaN      9662   Pave    NA
# 2414  528218130           60        RL          58.0     17104   Pave    NA
# 1989  902207150           30        RM          60.0      8520   Pave    NA
# 625   535105100           20        RL           NaN      9500   Pave    NA
#
#      Lot Shape Land Contour Utilities  ... 3Ssn Porch Screen Porch Pool Area  \
# Id                                     ...
# 2658       Reg          Lvl    AllPub  ...          0            0         0
# 2718       IR1          Lvl    AllPub  ...          0            0         0
# 2414       IR1          Lvl    AllPub  ...          0            0         0
# 1989       Reg          Lvl    AllPub  ...          0            0         0
# 625        IR1          Lvl    AllPub  ...          0          185         0
# ...

# %% [markdown]
# ## Drop Fields and Handle Case

# %%
kaggle.columns = [x.lower().replace(' ','_') for x in kaggle.columns]

# %%
kaggle.drop('pid', axis=1,inplace=True)

# %%
kaggle.drop('misc_val',axis=1,inplace=True)

# %% [markdown]
# ## Clean data in same method as training data

# %%
kaggle.fillna(
{'mas_vnr_type': 'None'
 ,'mas_vnr_area': 0.0
 ,'bsmt_exposure': 'No'
  ,'bsmt_qual': 'TA'
 ,'bsmt_cond': 'TA'
    ,'bsmtfin_type_1': 'GLQ'
    ,'bsmtfin_type_2': 'Unf'
    ,'garage_finish': 'Unf'
    ,'garage_qual': 'TA'
    ,'garage_cond': 'TA'
     ,'lot_frontage': 69.0
     ,'garage_yr_blt': 1978
     ,'bsmt_half_bath': 0.0
     ,'bsmt_full_bath': 0.0
     ,'garage_area': 0.0
     ,'garage_cars': 0.0
     ,'bsmtfin_sf_1': 368.0
     ,'bsmt_unf_sf': 0.0
     ,'bsmtfin_sf_2': 0.0
     ,'electrical': 'SBrkr'
}
,inplace=True)

# %%
kaggle.isna().sum().sum()
# Out:
# 0

# %%
kaggle.shape
# Out:
# (879, 77)

# %% [markdown]
# ## Get Dummies

# %%
test_kaggle = pd.get_dummies(kaggle)

# %%
test_kaggle.shape
# Out:
# (879, 284)

# %%
set(cols).difference(test_kaggle.columns)
# Out:
# {'misc_val'}

# %%
test_kaggle[cols].head()
# Out:
#       ms_subclass  lot_frontage  lot_area  overall_qual  overall_cond  \
# Id
# 2658          190          69.0      9142             6             8
# 2718           90          69.0      9662             5             4
# 2414           60          58.0     17104             7             5
# 1989           30          60.0      8520             5             6
# 625            20          69.0      9500             6             5
# 333           160          21.0      1890             4             6
# 1327           20          52.0      8516             4             6
# 858            20          69.0      9286             5             7
# 95            160          39.0      3515             7             5
# 1568           20          75.0     10125             6             6
# 2482          120          50.0      7175             6             5
# 1364           30          60.0      7200             6             7
# ...

# %%
test_kaggle['misc_val'] = 0

# %% [markdown]
# ## Scale data

# %%
kaggle_sc = ss.transform(test_kaggle[cols])
# Out:
# /Users/davidbickham/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by StandardScaler.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Make predictions

# %%
preds = lr.predict(kaggle_sc)

# %% [markdown]
# ## Align predictions back with index and set up header

# %%
submission = pd.DataFrame(preds, index=kaggle.index, columns=['SalePrice'])

# %% [markdown]
# ## Sort index (required for proper submission)

# %%
submission.sort_index(inplace=True)

# %% [markdown]
# ## Save to csv to submit

# %%
submission.to_csv('../data/numeric_only_lr.csv')

# %% [markdown]
# ## Use command line `head` to check data is correct format

# %%
# !head ../data/numeric_only_lr.csv
# Out:
# Id,SalePrice
# 2,106591.47113902813
# 4,270349.646516478
# 6,186409.64651647798
# 7,205740.64651647798
# 17,187743.64651647798
# 18,330631.22183108144
# 22,196276.47113902814
# 27,114689.47113902813
# 31,87446.646516478
